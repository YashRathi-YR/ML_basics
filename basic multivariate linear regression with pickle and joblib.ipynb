# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
# !pip install word2number
from word2number import w2n
# Out:
# ...
#   Using cached word2number-1.1-py3-none-any.whl
# ...

# %%
df=pd.read_csv("/content/hiring.csv")
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9       5000
# 1        NaN                    8.0                           6       4500
# 2       five                    6.0                           7       6000
# 3        two                   10.0                          10       6500
# 4      seven                    9.0                           6       7000
# 5      three                    7.0                          10       6200
# 6        ten                    NaN                           7       7200
# 7     eleven                    7.0                           8       8000

# %%
med=df['test_score(out of 10)'].median()

# %%
df['test_score(out of 10)']=df['test_score(out of 10)'].fillna(med)
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9       5000
# 1        NaN                    8.0                           6       4500
# 2       five                    6.0                           7       6000
# 3        two                   10.0                          10       6500
# 4      seven                    9.0                           6       7000
# 5      three                    7.0                          10       6200
# 6        ten                    8.0                           7       7200
# 7     eleven                    7.0                           8       8000

# %%
df.experience=df.experience.fillna('zero')
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0       zero                    8.0                           9       5000
# 1       zero                    8.0                           6       4500
# 2       five                    6.0                           7       6000
# 3        two                   10.0                          10       6500
# 4      seven                    9.0                           6       7000
# 5      three                    7.0                          10       6200
# 6        ten                    8.0                           7       7200
# 7     eleven                    7.0                           8       8000

# %%
df.experience = df.experience.apply(w2n.word_to_num)
df
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                    8.0                           9       5000
# 1           0                    8.0                           6       4500
# 2           5                    6.0                           7       6000
# 3           2                   10.0                          10       6500
# 4           7                    9.0                           6       7000
# 5           3                    7.0                          10       6200
# 6          10                    8.0                           7       7200
# 7          11                    7.0                           8       8000

# %%
df['salary($)']=df['salary($)']*10

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['experience','test_score(out of 10)','interview_score(out of 10)']],df['salary($)'])
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([2812.95487627, 1845.70596798, 2205.24017467])

# %%
reg.intercept_
# Out:
# 1773.7263464337711

# %%
reg.predict([[2,9,6]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([53205.96797671])

# %% [markdown]
# joblib n pickel are used to turn files or model into binary so that they can be shared or load model when needed

# %%
import joblib

# %%
joblib.dump(reg,'model_joblib')
# Out:
# ['model_joblib']

# %%
mj=joblib.load('model_joblib')

# %%
mj.predict([[2,9,6]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([53205.96797671])

# %%
import pickle

# %% [markdown]
#  with open('model_pickle','wb') as f:
#   pickle.dump(reg,f)

# %%
 with open('model_pickle','wb') as f:
  pickle.dump(reg,f)

# %%
 with open('model_pickle','rb') as f:
  mp= pickle.load(f)

# %%
mp.predict([[7,8,9]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([72040.75691412])
